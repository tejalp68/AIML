# %% [markdown]
# # DAY 03

# %% [markdown]
# - Name : Tejal Dadaji Pagar
# - Cohort : AIML & TEP cohort 2026
# - Day : Tuesday
# - Date : 11/08/2026
# - Description : this file is covering Loops, Flow Control & Modules. It has code and output for if conditions, while loop, for loop, break vs continue, range() with start/stop/step, and a bit of random and sys module usage, ending with a small "guess the number" game as practice

# %% [markdown]
# ### Loops,Flow Control & Modules

# %%
spam =0
if spam <5:
    print("Hello world")
    spam +=1
# Out:
# Hello world

# %% [markdown]
# #### While Loop

# %%
spam =0
while spam <5:
    print("Hello world")
    spam +=1
# Out:
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world

# %%
# name =""
# while name != 'your name':
#     print("Please type your name")
#     name =input(">")
# print("Thank you !")

# %% [markdown]
# ### Diff between break and continue
# - break terminates the block of code
# - continue only skips the condition that was true and doesnt execute

# %%
while True:
    print("Type your name")
    name =input(">")
    if name =="Your name":
        break
print("Thank you!")
# Out:
# Type your name
# > tejal
# Type your name
# > Your name
# Thank you!

# %%
for num in range(10):
    if num %2 ==0:
        continue
    print(num)
# Out:
# 1
# 3
# 5
# 7
# 9

# %% [markdown]
# #### FOR Loop

# %%
for i in range(5):
    print("Hello")
# Out:
# Hello
# Hello
# Hello
# Hello
# Hello

# %% [markdown]
# ### Range

# %%
# stop
for i in range(10):
    print("range")
# Out:
# range
# range
# range
# range
# range
# range
# range
# range
# range
# range

# %%
# start ,Stop
for i in range(2,15):
    print(i,"hey!")
# Out:
# 2 hey!
# 3 hey!
# 4 hey!
# 5 hey!
# 6 hey!
# 7 hey!
# 8 hey!
# 9 hey!
# 10 hey!
# 11 hey!
# 12 hey!
# 13 hey!
# 14 hey!

# %%
# start,stop,step
for i in range(1,10,2):
    print(i,"start")
# Out:
# 1 start
# 3 start
# 5 start
# 7 start
# 9 start

# %%
total =0
for i in range(101):
    total=total + i
print(total)
# Out:
# 5050

# %% [markdown]
# ### Modules

# %%
import random

#module_name.function_name(arguments)

# %%
random.randint(0,10)
# Out:
# 2

# %%
random.choices(["stone","paper","scissors"])
# Out:
# ['paper']

# %%
import sys
while True :
    print("Type to exit")
    response =input('>')
    if response =='exit':
        sys.exit()
    print("you typed " + response +'.')
# Out:
# Type to exit
# > hello
# you typed hello.
# Type to exit
# > guys
# you typed guys.
# Type to exit
# > what is this
# you typed what is this.
# Type to exit
# > exit
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %%
##### This is a guess the number game.
import random
secret_number = random.randint(1, 20)
print('I am thinking of a number between 1 and 20.')

print('I am thinking of a number between 1 and 20.')
# Ask the player to guess 6 times.
for guesses_taken in range(1, 7):
    print('Take a guess.')
    guess = int(input('>'))
    if guess < secret_number:
        print('Your guess is too low.')
    elif guess > secret_number:
        print('Your guess is too high.')
    else:
        break  # This condition is the correct guess!
if guess == secret_number:
    print('Good job! You got it in ' + str(guesses_taken) + ' guesses!')
else:
    print('Nope. The number was ' + str(secret_number))
# Out:
# I am thinking of a number between 1 and 20.
# I am thinking of a number between 1 and 20.
# Take a guess.
# > 20
# Your guess is too high.
# Take a guess.
# > 7
# Your guess is too high.
# Take a guess.
# > 9
# Your guess is too high.
# Take a guess.
# > 2
# Your guess is too low.
# Take a guess.
# > 3
# Good job! You got it in 5 guesses!
