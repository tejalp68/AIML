# %% [markdown]
# # DAY 04

# %% [markdown]
# - Name : Tejal Dadaji Pagar
# - Cohort : AIML & TEP cohort 2026
# - Day : Wednesday
# - Date : 12/08/2026
# - Description : this program involves functions definition,function calling ,global scope,local scope ,and error handling

# %% [markdown]
# # Functions And Error Handling

# %%
def hello():
    print('Hey')
    print('Hey')
    print('Hey')
hello()
hello()
print("one more time")
hello()
# Out:
# Hey
# Hey
# Hey
# Hey
# Hey
# Hey
# one more time
# Hey
# Hey
# Hey

# %%
## Parameter and Arguments are diff
#argument gets store in parameter

# %%
num1=int (input("Enter first number"))
num2=int (input("Enter Second number"))

def add(a,b):   #function defined #a,b parameters
    print(a+b)
add(num1,num2) #function calling #num1 and num2 are arguments
# Out:
# Enter first number 10
# Enter Second number 20
# 30

# %%
num1=int (input("Enter first number"))
num2=int (input("Enter Second number"))
def division_fun(a,b):
    print(a//b)
    print(a/b)
    print(a % b)
division_fun(num1,num2)
# Out:
# Enter first number 10
# Enter Second number 2
# 5
# 5.0
# 0

# %%
# the return value
def add(a,b):
    return a+b

# %%
result =add(10,20)

# %%
result
# Out:
# 30

# %%
spam =None
print(spam)   #use when value is absent
# Out:
# None

# %%
## Local scope

# %%
def spam():
    eggs='hi'
    print(eggs)
spam()
# Out:
# hi

# %%
## Global Variable

# %%
eggs = 'global value'
def spam():
    eggs =123
    print(eggs)
spam()
# Out:
# 123

# %%
eggs ='global'
def spam():
    eggs="Local" #rule of same name
    print(eggs) #local #rule of acccesing global var
spam()
print(eggs) #global
# Out:
# Local
# global

# %%
42/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 42/0
#
# ZeroDivisionError: division by zero

# %% [raw]
# # Ecxeption handling
# we write the code in try block that will throw an error
# and if error throws then except block will handle it

# %%
def divide_by(n):
    return 42/n
print(divide_by(2))
print(divide_by(14))
print(divide_by(0))
print(divide_by(3))
# Out:
# 21.0
# 3.0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[35], line 5
#       3 print(divide_by(2))
#       4 print(divide_by(14))
# ----> 5 print(divide_by(0))
#       6 print(divide_by(3))
#
# Cell In[35], line 2, in divide_by(n)
#       1 def divide_by(n):
# ----> 2     return 42/n
#
# ZeroDivisionError: division by zero

# %%
#try
#code that could potentially fail goes here -python attempts to run it normally

# %%
#except
#error gets handled here

# %%
def spam(divide_by):
    try:
        return 42/divide_by
    except ZeroDivisionError:
        print("Error:Invalid Argument")
print(spam(2))
print(spam(12))
print(spam(0))
print(spam(3))
# Out:
# 21.0
# 3.5
# Error:Invalid Argument
# None
# 14.0

# %%
#this is animation program 
import time, sys
indent = 0 # How many spaces to indent
indent_increasing = True # Whether the indentation is increasing or not
try:
    while True: # The main program loop
        print(' ' * indent, end='')
        print('********')
        time.sleep(0.1) # Pause for 1/10th of a second.
        if indent_increasing:
            # Increase the number of spaces:
            indent = indent + 1
    if indent == 20:
        # Change direction:
        indent_increasing = False
    else:
        # Decrease the number of spaces:
        indent = indent - 1
    if indent == 0:
        # Change direction:
        indent_increasing = True
except KeyboardInterrupt:
    sys.exit()
# Out:
# ********
#  ********
#   ********
#    ********
#     ********
#      ********
#       ********
#        ********
#         ********
#          ********
#           ********
#            ********
#             ********
#              ********
#               ********
#                ********
#                 ********
#                  ********
#                   ********
#                    ********
#                     ********
#                      ********
#                       ********
#                        ********
#                         ********
#                          ********
#                           ********
#                            ********
#                             ********
#                              ********
#                               ********
#                                ********
#                                 ********
#                                  ********
#                                   ********
# ...
